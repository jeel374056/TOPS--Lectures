# %%
print("wdbfwehb ejkhvberhvb",end="-")
print("fggrgrtgrtgrtg",end="******")
print("grgrtgrtgrtgrgrtgrtg")
# Out:
# wdbfwehb ejkhvberhvb-fggrgrtgrtgrtg******grgrtgrtgrtgrgrtgrtg

# %%
# types of comments
# single line #
# multi line

# """     """
# '''      '''

# %%
# Escape Sequence
print("jgjrtgrtb\ntgtgrt")
print("hello\tWorld")
print("gertgerger\"GFeg'erg")
print('egjerg e"rvne\'rerjui')
print("sdg\b\bfjks")
# Out:
# jgjrtgrtb
# tgtgrt
# hello	World
# gertgerger"GFeg'erg
# egjerg e"rvne'rerjui
# fjks

# %%
# variables
a=True  #boolean first letter should be uppercase
# print(a)
print(type(a))


int 56 64  4 4 46 
float 87.25 36.25 0. 015
string "dfgnfdgd"   'fdgbdfdgfd'
boolean True False Without Quotes
# Out:
# <class 'bool'>

# %%
a=58
# input("Mesaage")
# datatype(value/variable)
b=int(input("Enter Something: "))
print(type(b))
# input() by default take s values in string dtatatype we have to convert it in desired 
# as using type conversion
# Out:
# Enter Something: 85.36
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [45], in <cell line: 4>()
#       1 a=58
#       2 # input("Mesaage")
#       3 # datatype(value/variable)
# ----> 4 b=int(input("Enter Something: "))
#       5 print(type(b))
#
# ValueError: invalid literal for int() with base 10: '85.36'

# %%
name : Sugandh
age   :48
email  :sugandh2gmail.com
mobile: 896547859

your name is ______  you are _____ years old and your email is ______ and mobile is _________

# %%
# formatted Output
# f
a=48
b="sugandh"
c="sugandhsec112@gmail.com"
print(f"your name is {b} your age is {a} and email is {c}")
# Out:
# your name is sugandh your age is 48 and email is sugandhsec112@gmail.com

# %%
# operators
# Operators in Python
# Arithmetic operator  + - * / % **(power) //(floor division)
# comparison operator or conditional operator  < > <= >= == !=
# assignement operator = += -= *= /= 
# logical operator AND(and) OR(or) NOT(!)
# bitwise opeartor >> << & | ^
# identity operator is, is not
# membership operator in,not in

# %%
# Arithmetic operator
print(2**3)
print(36//5)
# Out:
# 8
# 7

# %%
# comparsion operator
a=48
b=39
print(a<b)
print(a>=b)
a=48
b=48
print(a==b)
print(a!=b)
x=89
y=56
print(x!=y)
# Out:
# False
# True
# True
# False
# True

# %%
# Logical operator
# and ----results false if any one condition is false it return true if all the condition is true 
# or---- reults true if minimum one condition is true and return false if all the condition is false
# not-----just reverse your answer
print (not(89>36))
# print(48<32)
# print((89>36) and (48<32))
# Out:
# False

# %%
a=48
# a=a+98 
a+=98 #short hand notation
print(a)
# Out:
# 146

# %%
print(89&36)
print(89>>3) 
print(89<<2)
# Out:
# 0
# 11
# 356

# %%
# conditional statements
# simple if
# if else
# if...elif..elif..else (ladder if else)
# nested if else

# %%
# simple if
if condition:
  body

# %%
a=int(input("Enter Age: "))
if a>18:
  print("adult")
# Out:
# Enter Age: 12

# %%
# if else
if condition:
  body of if
  fwef
  we
  fwe
  fwe
else:
  body of else

# %%
a=int(input("Enter Age: "))
if a>18:
  print("adult")
else:
  print("Not adult")
# Out:
# Enter Age: 12
# Not adult
